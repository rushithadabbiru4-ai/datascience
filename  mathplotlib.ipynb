# %% [markdown]
# <h1 style='color:blue'>Assignments related to MatplotLib
#     using Tips dataset</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### Draw bar graph showing total tip amount for each day

# %%
day_total = tips.groupby('day', as_index=False)['tip'].sum()
day_total
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\2236952094.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_total = tips.groupby('day', as_index=False)['tip'].sum()
#     day     tip
# 0  Thur  171.83
# 1   Fri   51.96
# 2   Sat  260.40
# 3   Sun  247.39

# %%
plt.bar(day_total['day'], day_total['tip'])
plt.title("Day-wise Total Tip")
plt.xlabel("Day")
plt.ylabel("Total Tip")
# Out:
# Text(0, 0.5, 'Total Tip')

# %% [markdown]
# #### Draw a pie chart showing total_bill for each day

# %%
day_total = tips.groupby('day', as_index=False)['total_bill'].sum()
day_total
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\1750048189.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_total = tips.groupby('day', as_index=False)['total_bill'].sum()
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
plt.pie(day_total['total_bill'], labels = day_total['day'], autopct ="%.2f")
plt.title("Day-wise Total Bill")
# Out:
# Text(0.5, 1.0, 'Day-wise Total Bill')

# %% [markdown]
# #### Display two pie charts - one for total bill amount for male and another for female -  for each day

# %%
male_bill = tips[(tips['sex'] == 'Male')].groupby('day', as_index=False)['total_bill'].sum()
female_bill = tips[(tips['sex'] == 'Female')].groupby('day', as_index=False)['total_bill'].sum()
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\1272952924.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   male_bill = tips[(tips['sex'] == 'Male')].groupby('day', as_index=False)['total_bill'].sum()
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\1272952924.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   female_bill = tips[(tips['sex'] == 'Female')].groupby('day', as_index=False)['total_bill'].sum()

# %%
fig,ax = plt.subplots(1,2)
fig.suptitle('Day-wise Total Bill by Gender', fontsize=14)
fig.set_size_inches(10,5)
ax[0].pie(male_bill['total_bill'], labels = male_bill['day'], autopct ="%.2f")
ax[0].set_title("Male Day-wise Total Bill")

ax[1].pie(female_bill['total_bill'], labels = female_bill['day'], autopct ="%.2f")
ax[1].set_title("Female Day-wise Total Bill")

# fig.savefig("Day_wise_Total_Bill_by_Gender.jpg")
# Out:
# Text(0.5, 1.0, 'Female Day-wise Total Bill')

# %%
#### Display a histogram for tip percentage

# %%
tip_per = tips['tip'] / tips['total_bill'] * 100
plt.hist(tip_per)
# Out:
# (array([ 31., 120.,  80.,  10.,   1.,   1.,   0.,   0.,   0.,   1.]),
#  array([ 3.56381359, 10.3108805 , 17.05794742, 23.80501434, 30.55208125,
#         37.29914817, 44.04621509, 50.79328201, 57.54034892, 64.28741584,
#         71.03448276]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Display a stacked bar for total bill of smokers and non-smokers for each day

# %%
smoker_total  = pd.crosstab(tips['day'], tips['smoker'], tips['total_bill'], aggfunc=sum)
smoker_total
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\758472525.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   smoker_total  = pd.crosstab(tips['day'], tips['smoker'], tips['total_bill'], aggfunc=sum)
# smoker     Yes       No
# day
# Thur    326.24   770.09
# Fri     252.20    73.68
# Sat     893.62   884.78
# Sun     458.28  1168.88

# %%
ax = plt.subplot()
ax.bar(smoker_total.index , height=smoker_total['Yes'])
ax.bar(smoker_total.index , height=smoker_total['No'],bottom = smoker_total["Yes"])
ax.legend(smoker_total.columns)

# %% [markdown]
# #### Display stacked bar for count of transactions for male and female for each day

# %%
gender_total  = pd.crosstab(tips['day'], tips['sex'], tips['total_bill'], aggfunc='count')
gender_total
# Out:
# sex   Male  Female
# day
# Thur    30      32
# Fri     10       9
# Sat     59      28
# Sun     58      18

# %% [markdown]
# #### Display scatter plot for tip amount and total bill for first 10 highest tip amounts

# %%
top_tip = tips.nlargest(10,'tip')
plt.scatter(top_tip['total_bill'], top_tip['tip'])
plt.title("Total Bill vs. Tip for top 10 tip amounts")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### Display scatter plot for tip percentage and size of the table where total_bill is more than 10

# %%
df = tips[(tips['total_bill'] > 10)]
df['tip_per'] = df['tip'] / df['total_bill'] * 100
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\1068284712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tip_per'] = df['tip'] / df['total_bill'] * 100

# %%
plt.scatter(df['size'], df['tip_per'])
plt.title("Size vs. Tip Percentage")
plt.xlabel("Size")
plt.ylabel("Tip Percentage")
# Out:
# Text(0, 0.5, 'Tip Percentage')

# %% [markdown]
# #### Display bar graph showing % of contribution each day has on total income

# %%
total = tips['total_bill'].sum()
df = tips.groupby('day')['total_bill'].sum()*100/total
df
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\4292966923.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = tips.groupby('day')['total_bill'].sum()*100/total
# day
# Thur    22.708828
# Fri      6.750114
# Sat     36.836883
# Sun     33.704174
# Name: total_bill, dtype: float64

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# #### Display a line graph for total tip amount for each day and show total at the points

# %%
day_total = tips.groupby('day', as_index=False)['tip'].sum()
day_total
# Out:
# C:\Users\vamsi\AppData\Local\Temp\ipykernel_17332\2236952094.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   day_total = tips.groupby('day', as_index=False)['tip'].sum()
#     day     tip
# 0  Thur  171.83
# 1   Fri   51.96
# 2   Sat  260.40
# 3   Sun  247.39

# %%
x = day_total['day']
y = day_total['tip']

plt.plot(x,y)
plt.title("Day-wise Total Tip")
plt.xlabel("Day")
plt.ylabel("Total Tip")

for a,b in zip(x, y): 
    plt.text(a, b, str(b))
